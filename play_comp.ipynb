# %%
from computational_modeling.computational_modeling import Computational_Modeling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
model = Computational_Modeling()
df = pd.read_csv('decisions_record.csv', true_values=['1'], false_values=['0'])
df.index = range(1, 101)

# %%
x, t, t_time = model.data_cleaning(df)

# %%
connection_weights, model_evaluation = model.train(x[1:], t[1:], t_time[1:], epochs=10)
# Out:
# C:\Users\maial\PycharmProjects\TFG_deliverable\venv\lib\site-packages\cma\evolution_strategy.py:1901: UserWarning: Sampling standard deviation i=0 at iteration 0 change by 0.6666666666666666 to stds[0]=0.6666666666666666
#   warnings.warn("Sampling standard deviation i={} at iteration {}"
# C:\Users\maial\PycharmProjects\TFG_deliverable\venv\lib\site-packages\cma\evolution_strategy.py:1901: UserWarning: Sampling standard deviation i=1 at iteration 0 change by 0.6666664884135709 to stds[1]=0.6666666666666666
#   warnings.warn("Sampling standard deviation i={} at iteration {}"
# C:\Users\maial\PycharmProjects\TFG_deliverable\venv\lib\site-packages\cma\evolution_strategy.py:1901: UserWarning: Sampling standard deviation i=2 at iteration 0 change by 0.666666310160523 to stds[2]=0.6666666666666666
#   warnings.warn("Sampling standard deviation i={} at iteration {}"
# ...

# %%
from data_visualization.data_visualization import Data_Visualization

dv = Data_Visualization()
dv.folder = r"C:\Users\maial\PycharmProjects\TFG_deliverable\storage_system\patient_93563858"
dv.df_to_csv(model_evaluation, "model_evaluation.csv")
dv.create_report(93563858)
# Out:
# C:/Users/maial/PycharmProjects/TFG_deliverable/storage_system/patient_93563858/plot_1.jpg
